# %%
import pandas as pd

df = pd.read_csv("PastHires.csv")
df.head(100)
# Out:
#     Years Experience Employed?  Previous employers Level of Education  \
# 0                 10         Y                   4                 BS
# 1                  0         N                   0                 BS
# 2                  7         N                   6                 BS
# 3                  2         Y                   1                 MS
# 4                 20         N                   2                PhD
# 5                  0         N                   0                PhD
# 6                  5         Y                   2                 MS
# 7                  3         N                   1                 BS
# 8                 15         Y                   5                 BS
# 9                  0         N                   0                 BS
# 10                 1         N                   1                PhD
# 11                 4         Y                   1                 BS
# ...

# %%
df.describe()
# Out:
#        Years Experience  Previous employers
# count         13.000000           13.000000
# mean           5.153846            1.769231
# std            6.348834            2.006400
# min            0.000000            0.000000
# 25%            0.000000            0.000000
# 50%            3.000000            1.000000
# 75%            7.000000            2.000000
# max           20.000000            6.000000

# %%
df.shape
# Out:
# (13, 7)

# %%
cols=len(df.axes[1])
print(cols)
# Out:
# 7

# %%
m=df["Previous employers"].mean()
print(m)
# Out:
# 1.7692307692307692

# %%
df.head(13)
# Out:
#     Years Experience Employed?  Previous employers Level of Education  \
# 0                 10         Y                   4                 BS
# 1                  0         N                   0                 BS
# 2                  7         N                   6                 BS
# 3                  2         Y                   1                 MS
# 4                 20         N                   2                PhD
# 5                  0         N                   0                PhD
# 6                  5         Y                   2                 MS
# 7                  3         N                   1                 BS
# 8                 15         Y                   5                 BS
# 9                  0         N                   0                 BS
# 10                 1         N                   1                PhD
# 11                 4         Y                   1                 BS
# ...

# %%
x = df["Previous employers"]
y = df["Years Experience"]

print(x)
print(y)
# Out:
# 0     4
# 1     0
# 2     6
# 3     1
# 4     2
# 5     0
# 6     2
# 7     1
# 8     5
# 9     0
# 10    1
# 11    1
# 12    0
# Name: Previous employers, dtype: int64
# 0     10
# 1      0
# 2      7
# 3      2
# 4     20
# 5      0
# 6      5
# 7      3
# 8     15
# 9      0
# 10     1
# 11     4
# 12     0
# Name: Years Experience, dtype: int64

# %%
import matplotlib.pyplot as plt 

x = df["Previous employers"]
y = df["Years Experience"]

plt.scatter(x, y)
plt.show()
